# %% [markdown]
# ¡Por supuesto! Aquí tienes una lista de ejercicios para practicar **Programación Orientada a Objetos (POO)** en Python. Estos ejercicios están diseñados para cubrir los conceptos clave como clases, objetos, herencia, encapsulamiento, polimorfismo y más. ¡Manos a la obra!
#
# ---
#
# ### **Ejercicios Básicos**
#
# 1. **Clase `Círculo`**:
#    - Crea una clase `Circulo` con un atributo `radio`.
#    - Añade métodos para calcular el área y la circunferencia.
#    - Crea un objeto de tipo `Circulo` y prueba los métodos.
#
# 2. **Clase `Rectángulo`**:
#    - Crea una clase `Rectangulo` con atributos `ancho` y `alto`.
#    - Añade métodos para calcular el área y el perímetro.
#    - Crea un objeto de tipo `Rectangulo` y prueba los métodos.
#
# 3. **Clase `Persona`**:
#    - Crea una clase `Persona` con atributos `nombre`, `edad` y `género`.
#    - Añade un método `presentarse` que imprima: "Hola, soy [nombre], tengo [edad] años y soy [género]".
#    - Crea un objeto de tipo `Persona` y llama al método `presentarse`.
#
# ---
#
# ### **Ejercicios Intermedios**
#
# 4. **Clase `CuentaBancaria`**:
#    - Crea una clase `CuentaBancaria` con atributos `titular` y `saldo`.
#    - Añade métodos para `depositar` y `retirar` dinero.
#    - Asegúrate de que no se pueda retirar más dinero del que hay en la cuenta.
#    - Crea un objeto de tipo `CuentaBancaria` y prueba los métodos.
#
# 5. **Clase `Coche`**:
#    - Crea una clase `Coche` con atributos `marca`, `modelo` y `kilometraje`.
#    - Añade un método `avanzar` que incremente el kilometraje en una cantidad dada.
#    - Crea un objeto de tipo `Coche` y prueba el método `avanzar`.
#
# 6. **Clase `Libro`**:
#    - Crea una clase `Libro` con atributos `titulo`, `autor` y `paginas`.
#    - Añade un método `descripcion` que imprima: "El libro [titulo] fue escrito por [autor] y tiene [paginas] páginas".
#    - Crea un objeto de tipo `Libro` y llama al método `descripcion`.
#
# ---
#
# ### **Ejercicios Avanzados**
#
# 7. **Herencia: `Animal` y `Perro`**:
#    - Crea una clase base `Animal` con atributos `nombre` y `edad`, y un método `hacer_sonido`.
#    - Crea una subclase `Perro` que herede de `Animal` y sobrescriba el método `hacer_sonido` para que devuelva "¡Guau!".
#    - Crea un objeto de tipo `Perro` y llama al método `hacer_sonido`.
#
# 8. **Polimorfismo: `Figura`**:
#    - Crea una clase base `Figura` con un método abstracto `area`.
#    - Crea subclases `Circulo` y `Rectangulo` que hereden de `Figura` y sobrescriban el método `area`.
#    - Crea una lista de figuras y calcula el área de cada una.
#
# 9. **Composición: `Coche` y `Motor`**:
#    - Crea una clase `Motor` con un método `encender`.
#    - Crea una clase `Coche` que tenga un atributo `motor` de tipo `Motor`.
#    - Añade un método `arrancar` en `Coche` que llame al método `encender` del motor.
#    - Crea un objeto de tipo `Coche` y prueba el método `arrancar`.
#
# 10. **Encapsulamiento: `CuentaSegura`**:
#     - Crea una clase `CuentaSegura` con un atributo privado `__saldo`.
#     - Añade métodos públicos `depositar` y `retirar` que modifiquen el saldo.
#     - Asegúrate de que no se pueda acceder directamente al saldo desde fuera de la clase.
#     - Crea un objeto de tipo `CuentaSegura` y prueba los métodos.
#
# ---
#
# ### **Ejercicios de Proyectos**
#
# 11. **Sistema de Gestión de Biblioteca**:
#     - Crea clases `Libro`, `Usuario` y `Biblioteca`.
#     - La clase `Biblioteca` debe permitir agregar libros, prestar libros a usuarios y devolver libros.
#     - Implementa métodos para mostrar los libros disponibles y los libros prestados.
#
# 12. **Sistema de Gestión de Empleados**:
#     - Crea una clase base `Empleado` con atributos `nombre`, `salario` y un método `calcular_bono`.
#     - Crea subclases `Gerente` y `Desarrollador` que hereden de `Empleado` y sobrescriban el método `calcular_bono` con lógicas diferentes.
#     - Crea una lista de empleados y calcula el bono de cada uno.
#
# 13. **Juego de Cartas**:
#     - Crea clases `Carta`, `Mazo` y `Jugador`.
#     - La clase `Mazo` debe permitir barajar, repartir cartas y mostrar el mazo.
#     - La clase `Jugador` debe permitir recibir cartas y mostrar su mano.
#     - Implementa un juego simple como "Guerra" o "Blackjack".
#
# 14. **Sistema de Reservas de Hotel**:
#     - Crea clases `Habitacion`, `Cliente` y `Hotel`.
#     - La clase `Hotel` debe permitir reservar habitaciones, liberar habitaciones y mostrar las habitaciones disponibles.
#     - Implementa métodos para calcular el costo total de la estadía.
#
# 15. **Simulación de un Zoo**:
#     - Crea una clase base `Animal` con atributos `nombre` y `edad`, y métodos `comer` y `dormir`.
#     - Crea subclases como `Leon`, `Elefante` y `Mono` que hereden de `Animal` y sobrescriban los métodos.
#     - Crea una clase `Zoo` que contenga una lista de animales y permita agregar animales, alimentarlos y hacerlos dormir.
#
# ---
#
# ### **Ejercicios Adicionales**
#
# 16. **Clase `Reloj`**:
#     - Crea una clase `Reloj` con atributos `hora`, `minuto` y `segundo`.
#     - Añade métodos para avanzar el tiempo y mostrar la hora actual.
#     - Implementa un método para reiniciar el reloj a 00:00:00.
#
# 17. **Clase `Fraccion`**:
#     - Crea una clase `Fraccion` con atributos `numerador` y `denominador`.
#     - Añade métodos para sumar, restar, multiplicar y dividir fracciones.
#     - Implementa un método para simplificar la fracción.
#
# 18. **Clase `Pila`**:
#     - Crea una clase `Pila` que simule una pila (estructura LIFO).
#     - Añade métodos para `apilar`, `desapilar` y `mostrar` la pila.
#     - Implementa un método para verificar si la pila está vacía.
#
# 19. **Clase `Cola`**:
#     - Crea una clase `Cola` que simule una cola (estructura FIFO).
#     - Añade métodos para `encolar`, `desencolar` y `mostrar` la cola.
#     - Implementa un método para verificar si la cola está vacía.
#
# 20. **Clase `Matriz`**:
#     - Crea una clase `Matriz` que permita crear matrices de tamaño NxM.
#     - Añade métodos para sumar, restar y multiplicar matrices.
#     - Implementa un método para transponer la matriz.
#
# ---
#
# ### **Consejos para Resolver los Ejercicios**
# 1. **Empieza con lo básico**: Define las clases, atributos y métodos principales.
# 2. **Prueba cada método**: Asegúrate de que cada funcionalidad funciona correctamente.
# 3. **Usa la herencia y el polimorfismo**: Aprovecha estos conceptos para reutilizar código.
# 4. **Experimenta**: Modifica los ejercicios para añadir nuevas funcionalidades.
#
# ¡Espero que estos ejercicios te ayuden a dominar la POO en Python! Si tienes dudas o necesitas ayuda con alguno, no dudes en preguntar. ¡Buena suerte! 🚀
